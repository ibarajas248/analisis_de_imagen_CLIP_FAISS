# %% [markdown]
# ### Paso 1
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
# !pip -q install pandas
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.

# %%
# !pip -q install pandas
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Paso 2
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
# !pip install pandas numpy faiss-cpu
#
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.

# %%
# !pip install pandas numpy faiss-cpu
# Out:
# Requirement already satisfied: pandas in c:\users\david\pycharmprojects\proyectos_organizados\humanidades_digitales\analisis_de_imagen\.venv\lib\site-packages (3.0.0)
# Requirement already satisfied: numpy in c:\users\david\pycharmprojects\proyectos_organizados\humanidades_digitales\analisis_de_imagen\.venv\lib\site-packages (2.4.1)
# Collecting faiss-cpu
#   Obtaining dependency information for faiss-cpu from https://files.pythonhosted.org/packages/87/ff/35ed875423200c17bdd594ce921abfc1812ddd21e09355290b9a94e170ab/faiss_cpu-1.13.2-cp312-cp312-win_amd64.whl.metadata
#   Using cached faiss_cpu-1.13.2-cp312-cp312-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\david\pycharmprojects\proyectos_organizados\humanidades_digitales\analisis_de_imagen\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\david\pycharmprojects\proyectos_organizados\humanidades_digitales\analisis_de_imagen\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: packaging in c:\users\david\pycharmprojects\proyectos_organizados\humanidades_digitales\analisis_de_imagen\.venv\lib\site-packages (from faiss-cpu) (26.0)
# Requirement already satisfied: six>=1.5 in c:\users\david\pycharmprojects\proyectos_organizados\humanidades_digitales\analisis_de_imagen\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached faiss_cpu-1.13.2-cp312-cp312-win_amd64.whl (18.9 MB)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.13.2
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Paso 3
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
# !pip install torch torchvision torchaudio
#
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.

# %%
# !pip install torch torchvision torchaudio
# Out:
# Collecting torch
#   Obtaining dependency information for torch from https://files.pythonhosted.org/packages/6e/01/624c4324ca01f66ae4c7cd1b74eb16fb52596dce66dbe51eff95ef9e7a4c/torch-2.10.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading torch-2.10.0-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Collecting torchvision
#   Obtaining dependency information for torchvision from https://files.pythonhosted.org/packages/ad/16/8f650c2e288977cf0f8f85184b90ee56ed170a4919347fc74ee99286ed6f/torchvision-0.25.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading torchvision-0.25.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting torchaudio
#   Obtaining dependency information for torchaudio from https://files.pythonhosted.org/packages/be/a0/da53c7d20fac15f66f8838653b91162de1bf21fb40fee88cf839e4ef5174/torchaudio-2.10.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading torchaudio-2.10.0-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Collecting filelock (from torch)
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/b5/36/7fb70f04bf00bc646cd5bb45aa9eddb15e19437a28b8fb2b4a5249fac770/filelock-3.20.3-py3-none-any.whl.metadata
#   Using cached filelock-3.20.3-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\david\pycharmprojects\proyectos_organizados\humanidades_digitales\analisis_de_imagen\.venv\lib\site-packages (from torch) (4.15.0)
# Collecting sympy>=1.13.3 (from torch)
#   Obtaining dependency information for sympy>=1.13.3 from https://files.pythonhosted.org/packages/a2/09/77d55d46fd61b4a135c444fc97158ef34a095e5681d0a6c10b75bf356191/sympy-1.14.0-py3-none-any.whl.metadata
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Obtaining dependency information for networkx>=2.5.1 from https://files.pythonhosted.org/packages/9e/c9/b2622292ea83fbb4ec318f5b9ab867d0a28ab43c5717bb85b0a5f6b3b0a4/networkx-3.6.1-py3-none-any.whl.metadata
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in c:\users\david\pycharmprojects\proyectos_organizados\humanidades_digitales\analisis_de_imagen\.venv\lib\site-packages (from torch) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch)
#   Obtaining dependency information for fsspec>=0.8.5 from https://files.pythonhosted.org/packages/01/c9/97cc5aae1648dcb851958a3ddf73ccd7dbe5650d95203ecb4d7720b4cdbf/fsspec-2026.1.0-py3-none-any.whl.metadata
#   Using cached fsspec-2026.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in c:\users\david\pycharmprojects\proyectos_organizados\humanidades_digitales\analisis_de_imagen\.venv\lib\site-packages (from torch) (80.10.2)
# Requirement already satisfied: numpy in c:\users\david\pycharmprojects\proyectos_organizados\humanidades_digitales\analisis_de_imagen\.venv\lib\site-packages (from torchvision) (2.4.1)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Obtaining dependency information for pillow!=8.3.*,>=5.3.0 from https://files.pythonhosted.org/packages/a7/87/90b358775a3f02765d87655237229ba64a997b87efa8ccaca7dd3e36e7a7/pillow-12.1.0-cp312-cp312-win_amd64.whl.metadata
#   Using cached pillow-12.1.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Obtaining dependency information for mpmath<1.4,>=1.1.0 from https://files.pythonhosted.org/packages/43/e3/7d92a15f894aa0c9c4b49b8ee9ac9850d6e63b03c9c32c0367a13ae62209/mpmath-1.3.0-py3-none-any.whl.metadata
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\david\pycharmprojects\proyectos_organizados\humanidades_digitales\analisis_de_imagen\.venv\lib\site-packages (from jinja2->torch) (3.0.3)
# Downloading torch-2.10.0-cp312-cp312-win_amd64.whl (113.8 MB)
#    ---------------------------------------- 0.0/113.8 MB ? eta -:--:--
#    ---------------------------------------- 0.2/113.8 MB 4.5 MB/s eta 0:00:26
#    ---------------------------------------- 0.3/113.8 MB 3.8 MB/s eta 0:00:30
#    ---------------------------------------- 0.6/113.8 MB 4.4 MB/s eta 0:00:26
#    ---------------------------------------- 0.7/113.8 MB 4.5 MB/s eta 0:00:26
#    ---------------------------------------- 0.9/113.8 MB 4.2 MB/s eta 0:00:27
#    ---------------------------------------- 1.1/113.8 MB 4.2 MB/s eta 0:00:27
#    ---------------------------------------- 1.3/113.8 MB 4.1 MB/s eta 0:00:28
#     --------------------------------------- 1.5/113.8 MB 4.2 MB/s eta 0:00:27
#     --------------------------------------- 1.6/113.8 MB 4.0 MB/s eta 0:00:28
#     --------------------------------------- 1.8/113.8 MB 4.0 MB/s eta 0:00:29
#     --------------------------------------- 2.0/113.8 MB 4.1 MB/s eta 0:00:28
#     --------------------------------------- 2.3/113.8 MB 4.1 MB/s eta 0:00:28
#     --------------------------------------- 2.4/113.8 MB 4.1 MB/s eta 0:00:28
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
# %%capture
# import pandas as pd
# df = pd.read_csv(
#     "obras_arte.csv",
#     encoding="utf-8"
# )
#
# print(df.head())
# print(df.shape)
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.

# %%
# %%capture
import pandas as pd
df = pd.read_csv(
    "obras_arte.csv",
    encoding="utf-8"
)

print(df.head())
print(df.shape)

# %% [markdown]
# ### Paso 6
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
# df
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.

# %%
df
# Out:
#           id   source                                         source_url  \
# 0       4428  thyssen  https://www.museothyssen.org/coleccion/artista...
# 1       4429  thyssen  https://www.museothyssen.org/coleccion/artista...
# 2       4430  thyssen  https://www.museothyssen.org/coleccion/artista...
# 3       4431  thyssen  https://www.museothyssen.org/coleccion/artista...
# 4       4432  thyssen  https://www.museothyssen.org/coleccion/artista...
# ...      ...      ...                                                ...
# 10726  15732    ARTIC  https://www.artic.edu/artworks/28697/woman-fig...
# 10727  15733    ARTIC  https://www.artic.edu/artworks/32060/i-coming-...
# 10728  15734    ARTIC  https://www.artic.edu/artworks/59924/albatross...
# 10729  15735    ARTIC  https://www.artic.edu/artworks/129118/so-then-...
# 10730  15736    ARTIC  https://www.artic.edu/artworks/91361/achira-ro...
#
#                                          source_url_sha1  \
# 0      b'\xd2\x9f\xcc\x04\xfb\n\x1eQ6\xe8(4m\xeb\x06\...
# 1      b'\x0c\x8e\xcbC\x02\x86-9|\xb7P\xbd\xab?2\xe0\...
# 2      b'>\x83\x17O\x05\xd4\x8f\r\xad\x95J[\x96\x8fo\...
# 3      b'\xc9\x9e5u\xe6d\x92\x97k\xfd>f\x92J1\xefV\x1...
# 4      b'\xa1\xec\x05\xd5\xc93\xf9\xc8I\xfd\x1b\xe3\x...
# ...                                                  ...
# 10726  b'(\xc8oA\xe2\x16\xd0\xa8\xff\xf8)\xab&0\xdd\x...
# 10727  b'\xf5\\7\xff\xe8GN\xe5~\xa9i\x9b\x9aW\xcb\xd6...
# 10728  b'pE9m\\G/\x9c\xbd\xf1\x08\xa8\x1b\x88A\x0cO\x...
# 10729   b'\xe5\xabr\xee6\xb1S\xa2\rLR1\x16`4\x1aW,\x1f;'
# 10730  b'y(\xb9\x8c\x94\x19\t\xefgp.\x8b\xb3)\x95\x14...
#
#                            inventory_no collection    room  \
# 0                  Nº INV.  ( DEC1656 )        NaN  Sala 2
# 1               Nº INV. 44.a ( 1931.4 )        NaN  Sala 2
# 2               Nº INV. 151 ( 1977.98 )        NaN  Sala 1
# 3      Nº INV. 44.d-e ( 1929.19.1-2.b )        NaN  Sala 2
# 4                Nº INV. 11 ( 1956.11 )        NaN  Sala 5
# ...                                 ...        ...     ...
# 10726                               NaN        NaN     NaN
# 10727                               NaN        NaN     NaN
# 10728                               NaN        NaN     NaN
# 10729                               NaN        NaN     NaN
# 10730                               NaN        NaN     NaN
#
#                                                 location  \
# 0      Thyssen-Bornemisza Collections, en depósito en...
# 1              Museo Nacional Thyssen-Bornemisza, Madrid
# 2              Museo Nacional Thyssen-Bornemisza, Madrid
# 3              Museo Nacional Thyssen-Bornemisza, Madrid
# 4              Museo Nacional Thyssen-Bornemisza, Madrid
# ...                                                  ...
# 10726                                            Chicago
# 10727                                            Chicago
# 10728                                            Chicago
# 10729                                            Chicago
# 10730                                            Chicago
#
#                                                    title  \
# 0                                    La Virgen y el Niño
# 1                               Tríptico de la Santa Faz
# 2                                         La Crucifixión
# 3      Tríptico de la Santa Faz (cerrado): La Anuncia...
# 4      Retrato póstumo de Wenceslao de Luxemburgo, du...
# ...                                                  ...
# 10726           Woman Figure with Medusa Ornaments, 1967
# 10727  “I”: Coming of Age, from the series “Tales of ...
# 10728   Albatrossi (Albatross) (Furnishing Fabric), 1967
# 10729                       “… So…then she sez… .”, 1993
# 10730                     Achira Root Vessel, 200–450 CE
#
#                         artist  ...  \
# 0               Anónimo alemán  ...
# 1              Maestro Bertram  ...
# 2                 Agnolo Gaddi  ...
# 3              Maestro Bertram  ...
# 4      Anónimo franco flamenco  ...
# ...                        ...  ...
# 10726          Claes Oldenburg  ...
# 10727        Katsukawa Shunsho  ...
# 10728              Maija Isola  ...
# 10729           Gladys Nilsson  ...
# 10730                    Nasca  ...
#
#                                               info_extra  bibliography  \
# 0      Esta pequeña escultura devocional en madera co...           NaN
# 1      Pintor, escultor e iluminador alemán del cambi...           NaN
# 2      Agnolo Gaddi es uno de los mejores representan...           NaN
# 3      Pintor, escultor e iluminador alemán del cambi...           NaN
# 4      El personaje representado se ha podido identif...           NaN
# ...                                                  ...           ...
# 10726                                                NaN           NaN
# 10727                                                NaN           NaN
# 10728  Art Institute of Chicago, European Decorative ...           NaN
# 10729                                                NaN           NaN
# 10730  Art Institute of Chicago, The Ancient Americas...           NaN
#
#        exhibition_hist                                          image_url  \
# 0                  NaN  https://www.museothyssen.org/sites/default/fil...
# 1                  NaN  https://www.museothyssen.org/sites/default/fil...
# 2                  NaN  https://www.museothyssen.org/sites/default/fil...
# 3                  NaN  https://www.museothyssen.org/sites/default/fil...
# 4                  NaN  https://www.museothyssen.org/sites/default/fil...
# ...                ...                                                ...
# 10726              NaN  https://www.artic.edu/iiif/2/4d5080ec-3718-49e...
# 10727              NaN  https://www.artic.edu/iiif/2/fa5b7e62-06ed-1de...
# 10728              NaN  https://www.artic.edu/iiif/2/f1a34741-98cb-7fd...
# 10729              NaN  https://www.artic.edu/iiif/2/b18a03bd-29a5-cf4...
# 10730              NaN  https://www.artic.edu/iiif/2/9546a61b-1249-173...
#
#                                           image_full_url raw_json  \
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                                                    NaN      NaN
# 3                                                    NaN      NaN
# 4                                                    NaN      NaN
# ...                                                  ...      ...
# 10726  https://www.artic.edu/iiif/2/4d5080ec-3718-49e...      NaN
# 10727  https://www.artic.edu/iiif/2/fa5b7e62-06ed-1de...      NaN
# 10728  https://www.artic.edu/iiif/2/f1a34741-98cb-7fd...      NaN
# 10729  https://www.artic.edu/iiif/2/b18a03bd-29a5-cf4...      NaN
# 10730  https://www.artic.edu/iiif/2/9546a61b-1249-173...      NaN
#
#                 scraped_at           updated_at  \
# 0      2026-01-20 23:47:41  2026-01-20 23:47:41
# 1      2026-01-20 23:47:41  2026-01-20 23:47:41
# 2      2026-01-20 23:47:41  2026-01-20 23:47:41
# 3      2026-01-20 23:47:41  2026-01-20 23:47:41
# 4      2026-01-20 23:47:41  2026-01-20 23:47:41
# ...                    ...                  ...
# 10726  2026-01-21 18:42:39  2026-01-21 18:42:39
# 10727  2026-01-21 18:42:40  2026-01-21 18:42:40
# 10728  2026-01-21 18:42:40  2026-01-21 18:42:40
# 10729  2026-01-21 18:42:40  2026-01-21 18:42:40
# 10730  2026-01-21 18:42:40  2026-01-21 18:42:40
#
#                                               title_norm  \
# 0                                    la virgen y el niño
# 1                               tríptico de la santa faz
# 2                                         la crucifixión
# 3      tríptico de la santa faz (cerrado): la anuncia...
# 4      retrato póstumo de wenceslao de luxemburgo, du...
# ...                                                  ...
# 10726           woman figure with medusa ornaments, 1967
# 10727  “i”: coming of age, from the series “tales of ...
# 10728   albatrossi (albatross) (furnishing fabric), 1967
# 10729                       “… so…then she sez… .”, 1993
# 10730                     achira root vessel, 200–450 ce
#
#                    artist_norm
# 0               anónimo alemán
# 1              maestro bertram
# 2                 agnolo gaddi
# 3              maestro bertram
# 4      anónimo franco flamenco
# ...                        ...
# 10726          claes oldenburg
# 10727        katsukawa shunsho
# 10728              maija isola
# 10729           gladys nilsson
# 10730                    nasca
#
# [10731 rows x 28 columns]

# %% [markdown]
# ### Paso 7
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
# df.columns
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.

# %%
df.columns
# Out:
# Index(['id', 'source', 'source_url', 'source_url_sha1', 'inventory_no',
#        'collection', 'room', 'location', 'title', 'artist', 'date_text',
#        'year_start', 'year_end', 'technique', 'medium', 'dimensions',
#        'size_text', 'description', 'info_extra', 'bibliography',
#        'exhibition_hist', 'image_url', 'image_full_url', 'raw_json',
#        'scraped_at', 'updated_at', 'title_norm', 'artist_norm'],
#       dtype='str')

# %% [markdown]
# # Leer índice FAISS

# %% [markdown]
# ### Paso 9
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
# import os
# import faiss
#
# INDEX_PATH = r"C:\Users\David\PycharmProjects\thyssen\clip_vitb32.index"  # <-- cambia esto
#
# INDEX_PATH = os.path.abspath(INDEX_PATH)
# index = faiss.read_index(INDEX_PATH)
# print("✅ Index cargado:", INDEX_PATH)
# print("ntotal:", index.ntotal)
#
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.

# %%
import os
import faiss

INDEX_PATH = r"C:\Users\David\PycharmProjects\thyssen\clip_vitb32.index"  # <-- cambia esto

INDEX_PATH = os.path.abspath(INDEX_PATH)
index = faiss.read_index(INDEX_PATH)
print("✅ Index cargado:", INDEX_PATH)
print("ntotal:", index.ntotal)
# Out:
# ✅ Index cargado: C:\Users\David\PycharmProjects\thyssen\clip_vitb32.index
# ntotal: 9957

# %% [markdown]
# ### Paso 10
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
# import numpy as np
# import faiss
#
# def get_faiss_ids(index) -> np.ndarray:
#     # Para IndexIDMap / IndexIDMap2, FAISS guarda los ids en index.id_map
#     if hasattr(index, "id_map"):
#         return faiss.vector_to_array(index.id_map).astype(np.int64)
#     raise TypeError("Este índice no tiene id_map (no es IDMap).")
#
# ids_faiss = get_faiss_ids(index)
# print("IDs en FAISS:", ids_faiss[:10], " ... total:", len(ids_faiss))
#
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.

# %%
import numpy as np
import faiss

def get_faiss_ids(index) -> np.ndarray:
    # Para IndexIDMap / IndexIDMap2, FAISS guarda los ids en index.id_map
    if hasattr(index, "id_map"):
        return faiss.vector_to_array(index.id_map).astype(np.int64)
    raise TypeError("Este índice no tiene id_map (no es IDMap).")

ids_faiss = get_faiss_ids(index)
print("IDs en FAISS:", ids_faiss[:10], " ... total:", len(ids_faiss))
# Out:
# IDs en FAISS: [4455 4456 4457 4462 4463 4464 4465 4466 4467 4468]  ... total: 9957

# %% [markdown]
# ### Paso 11
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
# import pandas as pd
# import numpy as np
#
# # asegura tipo
# df["id"] = pd.to_numeric(df["id"], errors="coerce").astype("Int64")
#
# # ordena según ids_faiss
# df_aligned = (
#     df.set_index("id")
#       .reindex(ids_faiss)          # respeta el orden del FAISS
#       .reset_index()
# )
#
# # filas que no existan en df quedan como NaN (por si el CSV no tiene todas)
# print(df_aligned.head())
# print("Filas alineadas:", len(df_aligned))
# print("Faltantes en df:", df_aligned["source"].isna().sum())
#
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.

# %%
import pandas as pd
import numpy as np

# asegura tipo
df["id"] = pd.to_numeric(df["id"], errors="coerce").astype("Int64")

# ordena según ids_faiss
df_aligned = (
    df.set_index("id")
      .reindex(ids_faiss)          # respeta el orden del FAISS
      .reset_index()
)

# filas que no existan en df quedan como NaN (por si el CSV no tiene todas)
print(df_aligned.head())
print("Filas alineadas:", len(df_aligned))
print("Faltantes en df:", df_aligned["source"].isna().sum())
# Out:
#      id   source                                         source_url  \
# 0  4455  thyssen  https://www.museothyssen.org/coleccion/artista...
# 1  4456  thyssen  https://www.museothyssen.org/coleccion/artista...
# 2  4457  thyssen  https://www.museothyssen.org/coleccion/artista...
# 3  4462  thyssen  https://www.museothyssen.org/coleccion/artista...
# 4  4463  thyssen  https://www.museothyssen.org/coleccion/artista...
#
#                                      source_url_sha1  \
# 0  b'S\xb1~t\xfb\xb8\x07\n\xaaQ\xa4S\xd1\x11\xdf~...
# 1  b'_\x1dW\xac\xdba\x03\x89\x94S)jl\xa6\x96=!\x8...
# 2  b'\xedh\xf6&\xb6\x9f\xc0\xeeD\x8dP2\xa4\xf9,\x...
# 3  b' \xe5\xd3\xe9u;\x14{\xeb\x94qzO\x06\xde\x0f\...
# 4  b'\xed\xe6~\xf2\xe6\xdbJ#T:\xc6<\x90\xcaa3\x90...
#
#                inventory_no collection                room  \
# 0   Nº INV. 210 ( 1929.13 )        NaN              Sala 2
# 1  Nº INV. 411 ( 1930.118 )        NaN              Sala 4
# 2    Nº INV. 162 ( 1966.6 )        NaN              Sala 1
# 3      Nº INV.  ( DEC1581 )        NaN  Sala no disponible
# 4    Nº INV. 261 ( 1931.2 )        NaN              Sala 3
#
#                                             location  \
# 0          Museo Nacional Thyssen-Bornemisza, Madrid
# 1          Museo Nacional Thyssen-Bornemisza, Madrid
# 2          Museo Nacional Thyssen-Bornemisza, Madrid
# 3  Thyssen-Bornemisza Collections, en depósito en...
# 4          Museo Nacional Thyssen-Bornemisza, Madrid
#
#                                                title  \
# 0                           La Asunción de la Virgen
# 1  La Crucifixión con la Virgen, los santos Juane...
# 2              Santa Catalina ante el Papa en Aviñón
# 3             La Virgen con el Niño y cuatro ángeles
# 4                                  Vestir al desnudo
#
#                                 artist  ...  \
# 0                     Johann Koerbecke  ...
# 1                        Paolo Uccello  ...
# 2                    Giovanni di Paolo  ...
# 3                   Agostino di Duccio  ...
# 4  Maestro de la Vista de Santa Gúdula  ...
#
#                                           info_extra  bibliography  \
# 0  Johann Koerbecke fue un pintor activo en Münst...           NaN
# 1  Vasari, que incluyó la biografía de Uccello en...           NaN
# 2  Santa Catalina, canonizada en 1461 por el papa...           NaN
# 3  Probablemente adquirido en 1935, este estuco p...           NaN
# 4  El Maestro de la Vista de Santa Gúdula fue un ...           NaN
#
#    exhibition_hist                                          image_url  \
# 0              NaN  https://www.museothyssen.org/sites/default/fil...
# 1              NaN  https://www.museothyssen.org/sites/default/fil...
# 2              NaN  https://www.museothyssen.org/sites/default/fil...
# 3              NaN  https://www.museothyssen.org/sites/default/fil...
# 4              NaN  https://www.museothyssen.org/sites/default/fil...
#
#   image_full_url raw_json           scraped_at           updated_at  \
# 0            NaN      NaN  2026-01-20 23:47:45  2026-01-20 23:47:45
# 1            NaN      NaN  2026-01-20 23:47:45  2026-01-20 23:47:45
# 2            NaN      NaN  2026-01-20 23:47:45  2026-01-20 23:47:45
# 3            NaN      NaN  2026-01-20 23:47:46  2026-01-20 23:47:46
# 4            NaN      NaN  2026-01-20 23:47:46  2026-01-20 23:47:46
#
#                                           title_norm  \
# 0                           la asunción de la virgen
# 1  la crucifixión con la virgen, los santos juane...
# 2              santa catalina ante el papa en aviñón
# 3             la virgen con el niño y cuatro ángeles
# 4                                  vestir al desnudo
#
#                            artist_norm
# 0                     johann koerbecke
# 1                        paolo uccello
# 2                    giovanni di paolo
# 3                   agostino di duccio
# 4  maestro de la vista de santa gúdula
#
# [5 rows x 28 columns]
# Filas alineadas: 9957
# Faltantes en df: 0

# %% [markdown]
# ### Paso 12
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
# df_in = df[df["id"].isin(ids_faiss)].copy()
# print("Solo obras presentes en FAISS:", df_in.shape)
#
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.

# %%
df_in = df[df["id"].isin(ids_faiss)].copy()
print("Solo obras presentes en FAISS:", df_in.shape)
# Out:
# Solo obras presentes en FAISS: (9957, 28)

# %% [markdown]
# ### Paso 13
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
# s = set(ids_faiss.tolist())
# df["in_faiss"] = df["id"].astype("Int64").apply(lambda x: int(x in s) if pd.notna(x) else 0)
#
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.

# %%
s = set(ids_faiss.tolist())
df["in_faiss"] = df["id"].astype("Int64").apply(lambda x: int(x in s) if pd.notna(x) else 0)

# %% [markdown]
# ### Paso 14
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
# import sys
# print(sys.executable)
#
#
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\David\PycharmProjects\proyectos_organizados\humanidades_digitales\analisis_de_imagen\.venv\Scripts\python.exe

# %% [markdown]
# ### Paso 15
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
# import numpy as np
# import pandas as pd
# import torch
# from transformers import CLIPModel, CLIPProcessor
#
# MODEL_NAME = "openai/clip-vit-base-patch32"
#
# device = "cuda" if torch.cuda.is_available() else "cpu"
# model = CLIPModel.from_pretrained(MODEL_NAME).to(device)
# processor = CLIPProcessor.from_pretrained(MODEL_NAME)
# model.eval()
#
# def text_embedding(text: str) -> np.ndarray:
#     tok = processor(
#         text=[text],
#         return_tensors="pt",
#         padding=True,
#         truncation=True
#     )
#     tok = {k: v.to(device) for k, v in tok.items()}
#
#     with torch.inference_mode():
#         # 1) pasa SOLO por el encoder de texto
#         text_out = model.text_model(
#             input_ids=tok["input_ids"],
#             attention_mask=tok.get("attention_mask", None),
#         )
#         # 2) pooler_output -> proyección CLIP a 512
#         v = text_out.pooler_output
#         v = model.text_projection(v)
#
#         # 3) normalizar para IndexFlatIP
#         v = v / v.norm(dim=-1, keepdim=True)
#
#     return v.detach().cpu().numpy().astype("float32")  # (1,512)
#
# def search_df(query: str, k: int = 10) -> pd.DataFrame:
#     q = text_embedding(query)             # (1,512)
#     D, I = index.search(q, k)             # I: (1,k) ids de obras, D: scores
#     ids = I[0].astype("int64")
#     scores = D[0]
#
#     # OJO: si algún id no está en df, lo filtramos
#     df_idx = df.set_index("id")
#     keep = [int(x) for x in ids if int(x) in df_idx.index]
#
#     out = (df_idx.loc[keep]
#                  .assign(score=scores[:len(keep)])
#                  .reset_index()
#                  .sort_values("score", ascending=False))
#     return out
#
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.

# %%
import numpy as np
import pandas as pd
import torch
from transformers import CLIPModel, CLIPProcessor

MODEL_NAME = "openai/clip-vit-base-patch32"

device = "cuda" if torch.cuda.is_available() else "cpu"
model = CLIPModel.from_pretrained(MODEL_NAME).to(device)
processor = CLIPProcessor.from_pretrained(MODEL_NAME)
model.eval()

def text_embedding(text: str) -> np.ndarray:
    tok = processor(
        text=[text],
        return_tensors="pt",
        padding=True,
        truncation=True
    )
    tok = {k: v.to(device) for k, v in tok.items()}

    with torch.inference_mode():
        # 1) pasa SOLO por el encoder de texto
        text_out = model.text_model(
            input_ids=tok["input_ids"],
            attention_mask=tok.get("attention_mask", None),
        )
        # 2) pooler_output -> proyección CLIP a 512
        v = text_out.pooler_output
        v = model.text_projection(v)

        # 3) normalizar para IndexFlatIP
        v = v / v.norm(dim=-1, keepdim=True)

    return v.detach().cpu().numpy().astype("float32")  # (1,512)

def search_df(query: str, k: int = 10) -> pd.DataFrame:
    q = text_embedding(query)             # (1,512)
    D, I = index.search(q, k)             # I: (1,k) ids de obras, D: scores
    ids = I[0].astype("int64")
    scores = D[0]

    # OJO: si algún id no está en df, lo filtramos
    df_idx = df.set_index("id")
    keep = [int(x) for x in ids if int(x) in df_idx.index]

    out = (df_idx.loc[keep]
                 .assign(score=scores[:len(keep)])
                 .reset_index()
                 .sort_values("score", ascending=False))
    return out
# Out:
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# CLIPModel LOAD REPORT from: openai/clip-vit-base-patch32
# Key                                  | Status     | Details
# -------------------------------------+------------+--------
# vision_model.embeddings.position_ids | UNEXPECTED |
# text_model.embeddings.position_ids   | UNEXPECTED |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# The image processor of type `CLIPImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %% [markdown]
# ### Paso 16
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
# qtext = input("🔎 Buscar: ")
# df_results = search_df(qtext, k=15)
#
# df_results[["id","title","artist","score","image_url"]].head(15)
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.

# %%
qtext = input("🔎 Buscar: ")   
df_results = search_df(qtext, k=15)

df_results[["id","title","artist","score","image_url"]].head(15)
# Out:
# 🔎 Buscar:  perro
#        id                                              title  \
# 0   13485                                        Pluto, 1989
# 1    6822                    Gian Lodovico Madruzzo, 1551–52
# 2    4678                           Retrato de Antonia Canis
# 3   10121                                     Ho-Mo-Vi, 1898
# 4    7971                            Christa and Wolfi, 1964
# 5    4833                           Bodegón con gato y raya.
# 6   11569  Rhyton (Drinking Vessel) in Shape of Sheep’s H...
# 7   13905  Fox, from The Picture Book of Realistic Painti...
# 8   15296                         The Actress Consuelo, 1901
# 9    4517                         San Jerónimo como cardenal
# 10   9941           Panel (Dress or Furnishing Fabric), 1924
# 11   9301                             Untitled (Devil), 1952
# 12  13499                          Figure of a Dog, 1–200 CE
# 13  11571                       Lion, Lioness and Cubs, n.d.
# 14  13791  “Strudel” with a Large Bone, Malibu, Californi...
#
#                           artist     score  \
# 0                   Lucian Freud  0.257051
# 1       Giovanni Battista Moroni  0.253057
# 2                Cornelis De Vos  0.252772
# 3          Elbridge Ayer Burbank  0.252653
# 4                Gerhard Richter  0.250969
# 5   Jean Baptiste Siméon Chardin  0.250000
# 6                  Ancient Greek  0.248004
# 7             Katsushika Hokusai  0.247656
# 8                Ignacio Zuloaga  0.247272
# 9          Maestro de Grossgmain  0.246430
# 10                    Léon Bakst  0.244069
# 11                 Pablo Picasso  0.244056
# 12                        Colima  0.243113
# 13     Giovanni Domenico Tiepolo  0.241969
# 14                Joel Sternfeld  0.241448
#
#                                             image_url
# 0   https://www.artic.edu/iiif/2/4a7a454b-b9f0-f2d...
# 1   https://www.artic.edu/iiif/2/bc24fe7f-4171-c78...
# 2   https://www.museothyssen.org/sites/default/fil...
# 3   https://www.artic.edu/iiif/2/c4d5ccf0-522a-cb8...
# 4   https://www.artic.edu/iiif/2/5ac548fe-ae9c-f23...
# 5   https://www.museothyssen.org/sites/default/fil...
# 6   https://www.artic.edu/iiif/2/33b10cd3-a55a-1a8...
# 7   https://www.artic.edu/iiif/2/3a14e0a9-e6a6-d25...
# 8   https://www.artic.edu/iiif/2/133acf1e-81b1-4bd...
# 9   https://www.museothyssen.org/sites/default/fil...
# 10  https://www.artic.edu/iiif/2/52eabd42-fb8a-e4f...
# 11  https://www.artic.edu/iiif/2/18d5e00d-b59f-c7c...
# 12  https://www.artic.edu/iiif/2/f8df8a30-eab8-eb4...
# 13  https://www.artic.edu/iiif/2/62cbb8f1-ad48-1a1...
# 14  https://www.artic.edu/iiif/2/a661c6d5-dda8-311...

# %% [markdown]
# ### Paso 17
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
# from IPython.display import Image, display
#
# top = df_results.head(10)
#
# for i, row in top.iterrows():
#     print(f"{row['title']} — {row['artist']} (score={row['score']:.3f})")
#     if pd.notna(row["image_url"]):
#         display(Image(url=row["image_url"], width=300))
#     print("-" * 60)
#
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.

# %%
from IPython.display import Image, display

top = df_results.head(10)

for i, row in top.iterrows():
    print(f"{row['title']} — {row['artist']} (score={row['score']:.3f})")
    if pd.notna(row["image_url"]):
        display(Image(url=row["image_url"], width=300))
    print("-" * 60)
# Out:
# Pluto, 1989 — Lucian Freud (score=0.257)
# <img src="https://www.artic.edu/iiif/2/4a7a454b-b9f0-f2d4-1f7c-57ab04ae8258/full/600,/0/default.jpg" width="300"/>
# ------------------------------------------------------------
# Gian Lodovico Madruzzo, 1551–52 — Giovanni Battista Moroni (score=0.253)
# <img src="https://www.artic.edu/iiif/2/bc24fe7f-4171-c785-bff2-b2ed3777a47d/full/600,/0/default.jpg" width="300"/>
# ------------------------------------------------------------
# Retrato de Antonia Canis — Cornelis De Vos (score=0.253)
# <img src="https://www.museothyssen.org/sites/default/files/styles/full_resolution/public/imagen/obras/1934.31_retrato-antonia-canis.jpg" width="300"/>
# ------------------------------------------------------------
# Ho-Mo-Vi, 1898 — Elbridge Ayer Burbank (score=0.253)
# <img src="https://www.artic.edu/iiif/2/c4d5ccf0-522a-cb8d-0e82-69577c8e1b49/full/600,/0/default.jpg" width="300"/>
# ------------------------------------------------------------
# Christa and Wolfi, 1964 — Gerhard Richter (score=0.251)
# <img src="https://www.artic.edu/iiif/2/5ac548fe-ae9c-f234-e7e0-e0a4e6dac669/full/600,/0/default.jpg" width="300"/>
# ------------------------------------------------------------
# Bodegón con gato y raya. — Jean Baptiste Siméon Chardin (score=0.250)
# <img src="https://www.museothyssen.org/sites/default/files/styles/full_resolution/public/imagen/obras/1986.6_bodegon-gato-raya.jpg" width="300"/>
# ------------------------------------------------------------
# Rhyton (Drinking Vessel) in Shape of Sheep’s Head, 320-310 BCE — Ancient Greek (score=0.248)
# <img src="https://www.artic.edu/iiif/2/33b10cd3-a55a-1a8b-fab0-460e3c87c470/full/600,/0/default.jpg" width="300"/>
# ------------------------------------------------------------
# Fox, from The Picture Book of Realistic Paintings of Hokusai (Hokusai shashin gafu), c. 1814 — Katsushika Hokusai (score=0.248)
# <img src="https://www.artic.edu/iiif/2/3a14e0a9-e6a6-d25a-a978-365341d27888/full/600,/0/default.jpg" width="300"/>
# ------------------------------------------------------------
# The Actress Consuelo, 1901 — Ignacio Zuloaga (score=0.247)
# <img src="https://www.artic.edu/iiif/2/133acf1e-81b1-4bd1-311e-f168697e80c9/full/600,/0/default.jpg" width="300"/>
# ------------------------------------------------------------
# San Jerónimo como cardenal — Maestro de Grossgmain (score=0.246)
# <img src="https://www.museothyssen.org/sites/default/files/styles/full_resolution/public/imagen/obras/1932.2_san-jeronimo-como-cardenal.jpg" width="300"/>
# ------------------------------------------------------------

# %% [markdown]
# ### Paso 18
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
# # =========================
# # IMAGEN -> IMAGEN (CLIP + FAISS)
# # =========================
#
# import numpy as np
# import pandas as pd
# import torch
# from PIL import Image
#
# # Requisitos previos (ya los tienes en tu notebook):
# # - df: DataFrame con columna 'id' (int) y campos como title/artist/image_url
# # - index: índice FAISS ya cargado
# # - model, processor: CLIPModel/CLIPProcessor cargados
# # - device: "cuda" o "cpu"
#
# def image_embedding_from_path(img_path: str) -> np.ndarray:
#     """Genera embedding CLIP (1,512) para una imagen local y lo normaliza."""
#     img = Image.open(img_path).convert("RGB")
#
#     inputs = processor(images=img, return_tensors="pt")
#     inputs = {k: v.to(device) for k, v in inputs.items()}
#
#     # capa de proyección (según versión/modelo)
#     proj = getattr(model, "visual_projection", None) or getattr(model, "vision_projection", None)
#     if proj is None:
#         raise AttributeError("No encuentro visual_projection/vision_projection en el modelo CLIP.")
#
#     with torch.inference_mode():
#         # encoder de visión (salida completa)
#         vision_out = model.vision_model(**inputs)
#
#         # pooler_output -> proyección a 512
#         v = proj(vision_out.pooler_output)  # (1,512)
#
#         # normalizar para IndexFlatIP (cosine)
#         v = v / v.norm(dim=-1, keepdim=True)
#
#     return v.detach().cpu().numpy().astype("float32")  # (1,512)
#
# def search_by_image(img_path: str, k: int = 10) -> pd.DataFrame:
#     """
#     Busca las k más similares en el índice FAISS usando una imagen externa.
#     Devuelve un DataFrame con score y metadatos del df.
#     """
#     q = image_embedding_from_path(img_path)   # (1,512)
#     D, I = index.search(q, k)                 # I: (1,k) ids o posiciones; D: (1,k) scores
#
#     ids = I[0].astype("int64")
#     scores = D[0]
#
#     # Caso típico: tu índice es IDMap y devuelve ids reales = df['id']
#     df_idx = df.set_index("id")
#     keep_ids = [int(x) for x in ids if int(x) in df_idx.index]
#
#     out = (df_idx.loc[keep_ids]
#            .assign(score=scores[:len(keep_ids)])
#            .reset_index()
#            .sort_values("score", ascending=False))
#     return out
#
# # ---- USO ----
# img_path = r"C:\Users\David\PycharmProjects\proyectos_organizados\humanidades_digitales\analisis_de_imagen\1986.3_bodegon-gato-pescado.jpg"
# df_sim = search_by_image(img_path, k=15)
# display(df_sim[["id","title","artist","score","image_url"]].head(15))
#
# # ---- MOSTRAR TOP IMÁGENES (opcional) ----
# from IPython.display import Image as IPyImage, display
#
# top = df_sim.head(10)
# for _, row in top.iterrows():
#     print(f"{row.get('title','')} — {row.get('artist','')} (score={row['score']:.3f})")
#     if pd.notna(row.get("image_url", None)):
#         display(IPyImage(url=row["image_url"], width=300))
#     print("-" * 60)
#
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.

# %%
# =========================
# IMAGEN -> IMAGEN (CLIP + FAISS)
# =========================

import numpy as np
import pandas as pd
import torch
from PIL import Image

# Requisitos previos (ya los tienes en tu notebook):
# - df: DataFrame con columna 'id' (int) y campos como title/artist/image_url
# - index: índice FAISS ya cargado
# - model, processor: CLIPModel/CLIPProcessor cargados
# - device: "cuda" o "cpu"

def image_embedding_from_path(img_path: str) -> np.ndarray:
    """Genera embedding CLIP (1,512) para una imagen local y lo normaliza."""
    img = Image.open(img_path).convert("RGB")

    inputs = processor(images=img, return_tensors="pt")
    inputs = {k: v.to(device) for k, v in inputs.items()}

    # capa de proyección (según versión/modelo)
    proj = getattr(model, "visual_projection", None) or getattr(model, "vision_projection", None)
    if proj is None:
        raise AttributeError("No encuentro visual_projection/vision_projection en el modelo CLIP.")

    with torch.inference_mode():
        # encoder de visión (salida completa)
        vision_out = model.vision_model(**inputs)

        # pooler_output -> proyección a 512
        v = proj(vision_out.pooler_output)  # (1,512)

        # normalizar para IndexFlatIP (cosine)
        v = v / v.norm(dim=-1, keepdim=True)

    return v.detach().cpu().numpy().astype("float32")  # (1,512)

def search_by_image(img_path: str, k: int = 10) -> pd.DataFrame:
    """
    Busca las k más similares en el índice FAISS usando una imagen externa.
    Devuelve un DataFrame con score y metadatos del df.
    """
    q = image_embedding_from_path(img_path)   # (1,512)
    D, I = index.search(q, k)                 # I: (1,k) ids o posiciones; D: (1,k) scores

    ids = I[0].astype("int64")
    scores = D[0]

    # Caso típico: tu índice es IDMap y devuelve ids reales = df['id']
    df_idx = df.set_index("id")
    keep_ids = [int(x) for x in ids if int(x) in df_idx.index]

    out = (df_idx.loc[keep_ids]
           .assign(score=scores[:len(keep_ids)])
           .reset_index()
           .sort_values("score", ascending=False))
    return out

# ---- USO ----
img_path = r"C:\Users\David\PycharmProjects\proyectos_organizados\humanidades_digitales\analisis_de_imagen\1986.3_bodegon-gato-pescado.jpg"
df_sim = search_by_image(img_path, k=15)
display(df_sim[["id","title","artist","score","image_url"]].head(15))

# ---- MOSTRAR TOP IMÁGENES (opcional) ----
from IPython.display import Image as IPyImage, display

top = df_sim.head(10)
for _, row in top.iterrows():
    print(f"{row.get('title','')} — {row.get('artist','')} (score={row['score']:.3f})")
    if pd.notna(row.get("image_url", None)):
        display(IPyImage(url=row["image_url"], width=300))
    print("-" * 60)
# Out:
#        id                                              title  \
# 0    4832                         Bodegón con gato y pescado
# 1    4833                           Bodegón con gato y raya.
# 2    6698                            Fish (Still Life), 1864
# 3    4830     Bodegón con almirez,cántaro y caldero de cobre
# 4    4731  Bodegón con fuente china, copa, cuchillo, pan ...
# 5    9456                          North River Shad, c. 1910
# 6   12099  Sketches of Tigers and Men in 16th Century Cos...
# 7   11716                     Winter: Cat on a Cushion, 1909
# 8    8868           Portrait of Emily Crane Chadbourne, 1922
# 9   10166                               The Cock Fight, 1885
# 10  15388  Still Life with Eggs and a Leg of Mutton, 1780–90
# 11   4757               Bodegón con porcelana y copa nautilo
# 12   7764  Still Life with Monkey, Fruits, and Flowers, 1724
# 13   6682               Still Life with Game Fowl, c. 1600–3
# 14  12309                  Dead Birds and Shot Bags, c. 1660
#
#                                       artist     score  \
# 0               Jean Baptiste Siméon Chardin  0.998907
# 1               Jean Baptiste Siméon Chardin  0.860254
# 2                              Édouard Manet  0.832818
# 3               Jean Baptiste Siméon Chardin  0.815059
# 4   Atribuido a Jan Jansz. van de  Velde III  0.806045
# 5                      William Merritt Chase  0.801236
# 6                           Eugène Delacroix  0.789251
# 7        Théophile-Alexandre Pierre Steinlen  0.787222
# 8                         Tsugouharu Foujita  0.785938
# 9                              Winslow Homer  0.782753
# 10                             French School  0.782237
# 11                               Willem Kalf  0.779604
# 12                       Jean-Baptiste Oudry  0.777846
# 13                        Juan Sánchez Cotán  0.776702
# 14                               Pieter Boel  0.775698
#
#                                             image_url
# 0   https://www.museothyssen.org/sites/default/fil...
# 1   https://www.museothyssen.org/sites/default/fil...
# 2   https://www.artic.edu/iiif/2/0cbe27e8-2fec-344...
# 3   https://www.museothyssen.org/sites/default/fil...
# 4   https://www.museothyssen.org/sites/default/fil...
# 5   https://www.artic.edu/iiif/2/1792802f-9146-cd5...
# 6   https://www.artic.edu/iiif/2/e45249cf-d032-ea6...
# 7   https://www.artic.edu/iiif/2/e8e67721-bbb1-d00...
# 8   https://www.artic.edu/iiif/2/ab952f7c-03cb-185...
# 9   https://www.artic.edu/iiif/2/02512586-e9ae-530...
# 10  https://www.artic.edu/iiif/2/37981a95-ee40-e07...
# 11  https://www.museothyssen.org/sites/default/fil...
# 12  https://www.artic.edu/iiif/2/293ab61e-5536-c2d...
# 13  https://www.artic.edu/iiif/2/f2021182-1302-f76...
# 14  https://www.artic.edu/iiif/2/add1be75-4581-568...
# Bodegón con gato y pescado — Jean Baptiste Siméon Chardin (score=0.999)
# <img src="https://www.museothyssen.org/sites/default/files/styles/full_resolution/public/imagen/obras/1986.3_bodegon-gato-pescado.jpg" width="300"/>
# ------------------------------------------------------------
# Bodegón con gato y raya. — Jean Baptiste Siméon Chardin (score=0.860)
# <img src="https://www.museothyssen.org/sites/default/files/styles/full_resolution/public/imagen/obras/1986.6_bodegon-gato-raya.jpg" width="300"/>
# ------------------------------------------------------------
# Fish (Still Life), 1864 — Édouard Manet (score=0.833)
# <img src="https://www.artic.edu/iiif/2/0cbe27e8-2fec-3445-bc48-ce40a8f2dc25/full/600,/0/default.jpg" width="300"/>
# ------------------------------------------------------------
# Bodegón con almirez,cántaro y caldero de cobre — Jean Baptiste Siméon Chardin (score=0.815)
# <img src="https://www.museothyssen.org/sites/default/files/styles/full_resolution/public/imagen/2023-10/CHARDIN%2C%20Jean%20Baptiste%20Simeon_Bodegon%20con%20almirez%2C%20cantaro%20y%20caldero%20de%20cobre_118%20%281930.14%29_0.jpg" width="300"/>
# ------------------------------------------------------------
# Bodegón con fuente china, copa, cuchillo, pan y frutas — Atribuido a Jan Jansz. van de  Velde III (score=0.806)
# <img src="https://www.museothyssen.org/sites/default/files/styles/full_resolution/public/imagen/2017-12/VELDE%20III%20%28atrib%29_Bodeg%C3%B3n%20con%20fuente%20china%2C%20copa%2C..._376%20%281930.111%29%20%23DIG9.jpg" width="300"/>
# ------------------------------------------------------------
# North River Shad, c. 1910 — William Merritt Chase (score=0.801)
# <img src="https://www.artic.edu/iiif/2/1792802f-9146-cd55-2864-f5dc24c65377/full/600,/0/default.jpg" width="300"/>
# ------------------------------------------------------------
# Sketches of Tigers and Men in 16th Century Costume, 1828–29 — Eugène Delacroix (score=0.789)
# <img src="https://www.artic.edu/iiif/2/e45249cf-d032-ea64-ec58-aff860e20ac4/full/600,/0/default.jpg" width="300"/>
# ------------------------------------------------------------
# Winter: Cat on a Cushion, 1909 — Théophile-Alexandre Pierre Steinlen (score=0.787)
# <img src="https://www.artic.edu/iiif/2/e8e67721-bbb1-d007-82bd-c430ea73db70/full/600,/0/default.jpg" width="300"/>
# ------------------------------------------------------------
# Portrait of Emily Crane Chadbourne, 1922 — Tsugouharu Foujita (score=0.786)
# <img src="https://www.artic.edu/iiif/2/ab952f7c-03cb-1850-a855-e2b8af8f57cc/full/600,/0/default.jpg" width="300"/>
# ------------------------------------------------------------
# The Cock Fight, 1885 — Winslow Homer (score=0.783)
# <img src="https://www.artic.edu/iiif/2/02512586-e9ae-5300-eb9d-82350fd358a4/full/600,/0/default.jpg" width="300"/>
# ------------------------------------------------------------

# %% [markdown]
# ### Paso 19
#
# Esta celda ejecuta el siguiente bloque de código.
# **Objetivo:** documentar claramente qué hace este paso dentro del flujo general del análisis.
#
# ```python
#
# ```
#
# **Descripción funcional:**
# - Inicializa o ejecuta una parte del pipeline de análisis de imagen.
# - Se mantiene **idéntico** al código original, sin modificaciones.
